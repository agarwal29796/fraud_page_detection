# %% [markdown]
# ### Data Exploration :

# %% [markdown]
# file:///home/archit/Downloads/complete_guide_of_project%20(1).pdf

# %% [markdown]
# ### Features based on web content information (including HTML and Script source code)

# %%
import requests
import urllib.request
from urllib.request import urlopen
import time
from bs4 import BeautifulSoup
import re

# %%
url = 'http://web.mta.info/developers/turnstile.html'
# url = 'https://www.google.com'
# url = "https://www.w3schools.com/tags/tryit.asp?filename=tryhtml_iframe"
# url = "https://stackoverflow.com/questions/30498751/scraping-data-from-a-javascript-code-that-is-present-inside-an-html-file"
try :
    response = requests.get(url)
except : 
    response = None

# %%
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.findAll('a')[2]
# Out:
# <a href="/accessibility">Accessibility</a>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <html lang="en">
#  <head>
#   <title>
#    mta.info | Turnstile Data
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!--<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7">-->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="/siteimages/favicon.ico" rel="shortcut icon"/>
#   <link href="/css/base.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/grid.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/topbar.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/formalize.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="/css/jquery.datepick.css"> -->
#   <script language="javascript" src="/js/jquery-1.4.4.min.js" type="text/javascript">
#   </script>
# ...

# %%
ifs  = soup.findAll('iframe')
for frame in ifs : 
    print(frame.width)

# %% [markdown]
# ### No of scripts :

# %%
all_scripts = soup.findAll('script')
print(len(all_scripts))
for ss in all_scripts:
    try:
        print(ss['src'])
    except :
        print({})
# Out:
# 8
# /js/jquery-1.4.4.min.js
# /js/csshorizontalmenu.js
# {}
# {}
# {}
# {}
# {}
# //www.googleadservices.com/pagead/conversion.js

# %% [markdown]
# ###  Malicious Javascript

# %% [markdown]
# https://swag.cispa.saarland/papers/fass2018jast.pdf<br>
# https://github.com/Aurore54F/JaSt

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("--headless")
options.add_argument('/home/archit/sem2/ai/chromedriver/chromedriver')

browser = webdriver.Chrome('/home/archit/sem2/ai/chromedriver/chromedriver', options=options)

# browser = webdriver.Chrome('/home/archit/sem2/ai/chromedriver/chromedriver')

browser.get("https://sqa.stackexchange.com/questions/12755/selenium-webdriver-with-python-cannot-find-dynamic-content")

soup = BeautifulSoup(browser.page_source, "html.parser")
# l = [i.get('src') for i in soup.find_all('script') if i.get('src')]


scripts = soup.findAll('script')



# scripts = browser.find_elements_by_tag_name('script')
# # nav = browser.find_element_by_id("mainnav")


for sc in scripts:
    print("=================")
#     print(sc)
    
    try :
        src = sc['src']
    except :
        src = None 
    
    if src is None :
        txt = sc.text
    else :
        try :
            txt = urlopen(src).read().decode('utf-8')
        except :
            txt = None
            check = True
    
#     if check is True :
#         try :
#             txt = urlopen(src_url + src).read().decode('utf-8')
#         except : 
#             txt  = None
        
        
    print("src = ",end = '')
    print(src)        
    
#     try : 
#         src  = sc.get_attribute('src')
#     except :
#         src = None
        
#     if src is not None :
#         txt =  browser.get(src)
#     else:
#         txt = sc.get_attribute("innerHTML")
        
#     print(src)
#     print(txt)
    
    result1 = re.findall('\".+\"', txt)
    result2 = re.findall("\'.+\'", txt)
    result = result1 + result2
    print(len(result))
# Out:
# ...
# src = https://rules.quantcount.com/rules-p-c1rF4kxgLUzNc.js
# 0
# ...
# src = https://secure.quantserve.com/quant.js
# 22
# ...
# src = https://sb.scorecardresearch.com/beacon.js
# 2
# ...
# src = https://www.google-analytics.com/analytics.js
# 71
# ...
# src = https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js
# 7
# ...
# src = https://cdn.sstatic.net/Js/stub.en.js?v=31bd0a8f20e1
# 4
# ...
# src = None
# 6
# ...
# src = None
# 3
# ...
# src = None
# 3
# ...
# src = https://cdn.sstatic.net/Js/full-anon.en.js?v=af15fa7b1fbb
# 12
# ...
# src = https://cdn.sstatic.net/Js/post-validation.en.js?v=1a7f91c8fa5f
# 2
# ...
# src = https://cdn.sstatic.net/Js/prettify-full.en.js?v=6f81f0bd9830
# 4
# ...
# src = https://cdn.sstatic.net/Js/external-editor.en.js?v=2b7327372e32
# 2
# ...
# src = None
# 0
# ...
# src = None
# 14
# ...
# src = None
# 9
# ...
# src = None
# 1
# ...
# src = None
# 1
# ...
# src = None
# 1
# ...
# src = None
# 0
# ...
# src = None
# 13

# %%
def long_strings_count(url) :
    options = Options()
    options.add_argument("--headless")
    options.add_argument('/home/archit/sem2/ai/chromedriver/chromedriver')

    browser = webdriver.Chrome('/home/archit/sem2/ai/chromedriver/chromedriver', options=options)
    browser.get(url)
    soup = BeautifulSoup(browser.page_source, "html.parser")
    scripts = soup.findAll('script')
    count = 0
    
    for sc in scripts:
        check = False
        try :
            src = sc['src']
        except :
            src = None 
        
        if src is None :
            txt = sc.text
        else :
            try :
                txt = urlopen(src).read().decode('utf-8')
            except :
                txt = None
                check = True
    
        if check is True :
            try :
                txt = urlopen(url + src).read().decode('utf-8')
            except : 
                txt  = None
                

        
        result1 = re.findall('\".+\"', txt)
        result2 = re.findall("\'.+\'", txt)
        result = result1 + result2
    
    
    
        for ele in result1 :
            if len(ele) >= 50 :
                count += 1
        for ele in result2 :
            if len(ele) >= 50 :
                count += 1
    
    return count

# %%
count = long_strings_count("https://www.w3schools.com/tags/tryit.asp?filename=tryhtml_iframe")

# %%
print(count)
# Out:
# 782

# %%
def mal_js(url, file_name) :
    options = Options()
    options.add_argument("--headless")
    options.add_argument('/home/archit/sem2/ai/chromedriver/chromedriver')

    browser = webdriver.Chrome('/home/archit/sem2/ai/chromedriver/chromedriver', options=options)
    browser.get(url)
    soup = BeautifulSoup(browser.page_source, "html.parser")
    scripts = soup.findAll('script')
    count = 0
    file = open(file_name, 'a')
    for sc in scripts:
        check = False
        try :
            src = sc['src']
        except :
            src = None 
        
        if src is None :
            txt = sc.text
        else :
            try :
                txt = urlopen(src).read().decode('utf-8')
            except :
                txt = None
                check = True
    
        if check is True :
            try :
                txt = urlopen(url + src).read().decode('utf-8')
            except : 
                txt  = None
        
        file.write(txt)

    file.close()
    print("file written")

# %%
mal_js("https://sqa.stackexchange.com/questions/12755/selenium-webdriver-with-python-cannot-find-dynamic-content",  "check.js")
# Out:
# file written

# %%
def find_list_resources(tag, attribute,soup):
    list = []
    for x in soup.findAll(tag):
        try:
            list.append(x[attribute])
        except KeyError:
            pass
    return(list)


def iframe_count(url):
    try :
        response = requests.get(url)
    except : 
        response = None
        
    if response is None :
        return None
    
    soup = BeautifulSoup(response.text, "html.parser")
    return len(soup.findAll('iframe'))
    
    
        
def scripts_count(url) :
    try :
        response = requests.get(url)
    except : 
        response = None
        
    if response is None :
        return None
    
    soup = BeautifulSoup(response.text, "html.parser")
    return len(soup.findAll('script'))


def external_url_count(url) :
    try :
        response = requests.get(url)
    except : 
        response = None
    
    if response is None :
        return None
    
    soup = BeautifulSoup(response.text, "html.parser")
    count = 0
    count += len(find_list_resources('img',"src",soup))   
    count += len(find_list_resources('script',"src",soup))    
    count += len(find_list_resources("link","href",soup))
    count += len(find_list_resources("video","src",soup))         
    count += len(find_list_resources("audio","src",soup)) 
    count += len(find_list_resources("iframe","src",soup))
    count += len(find_list_resources("embed","src",soup))
    count += len(find_list_resources("object","data",soup))         
    count += len(find_list_resources("source","src",soup))
    return count

# %%
print(external_url_count('http://web.mta.info/developers/turnstile.html'))
# Out:
# <Response [200]>
# 13

# %%
print(iframe_count('http://web.mta.info/developers/turnstile.html'))
# Out:
# 0

# %%
print(scripts_count('http://web.mta.info/developers/turnstile.html'))
# Out:
# 8
